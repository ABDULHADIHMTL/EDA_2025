# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv('Visadataset.csv')
visa_df

cat_cols=visa_df.select_dtypes(include='object').columns
num_cols=visa_df.select_dtypes(exclude='object').columns
num_cols,cat_cols
# Out:
# (Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'),
#  Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'))

# %% [markdown]
# - Generally data has three types
#
#     - positive skew
#
#     - Negative skew
#
#     - No skew
#
# - skew ness happened because of outliers
#
# - eventhough we treat the outliers still we can see some skew
#
# - And we know that all the math developed by making an assumption as **Data follows Normal distribution**
#
# - so transformation methods used to convert data to normal
#
# - The important Transformations are
#
#     - Log Transformation
#
#     - Reciprocal Transformation
#
#     - Sqrt Transformation
#
#     - Exponential Transformation
#
#     - Power Transformation

# %% [markdown]
# *STEP-1*

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# *Step-2*

# %% [markdown]
# **read exponential data**

# %%
np.random.exponential(size=10000)
# Out:
# array([0.14980009, 1.58141365, 0.09488454, ..., 1.08783625, 1.38587348,
#        0.51997466])

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([1.14263767, 2.43455133, 0.07673977, ..., 1.0157811 , 0.97954997,
#        4.38687437])

# %% [markdown]
# *step-3:*

# %% [markdown]
# **plot histogram**

# %%
plt.hist(exp_data)
# Out:
# (array([6.051e+03, 2.389e+03, 9.950e+02, 3.350e+02, 1.460e+02, 5.500e+01,
#         1.800e+01, 6.000e+00, 4.000e+00, 1.000e+00]),
#  array([1.59110939e-04, 9.44732480e-01, 1.88930585e+00, 2.83387922e+00,
#         3.77845259e+00, 4.72302596e+00, 5.66759933e+00, 6.61217269e+00,
#         7.55674606e+00, 8.50131943e+00, 9.44589280e+00]),
#  <BarContainer object of 10 artists>)

# %%
# I want to convert the above exponential to normal distribution

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.distplot(exp_data)
# Out:
# <Axes: ylabel='Density'>

# %%
np.random.normal(size=100000)
# Out:
# array([ 1.15797288, -1.35874887, -0.28698603, ...,  1.19229615,
#         0.14762642, -0.18350657])

# %%
#  let us give variant name 
normal_data=np.random.normal(size=100000)
normal_data
# Out:
# array([ 0.2849554 ,  1.88804357, -0.93019996, ..., -0.58115802,
#        -0.10858709, -0.09815648])

# %%
plt.hist(normal_data)
plt.show()

# %% [markdown]
# **Goal**
#
# - Convert Exponential data to Normal data

# %% [markdown]
# **Log Transformation**
#
#   - log transformation means performing logarithm operations on original data
#
#   - It is one of the approach to convert data to Normality
#
#   - Log means natural logarithm base=e

# %%
x=2
np.log(x)
# Out:
# np.float64(0.6931471805599453)

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([ 0.13333934,  0.88976248, -2.56733515, ...,  0.01565788,
#        -0.02066203,  1.47861698])

# %%
# we are hoping log data might follows normality
# it might be possible or might not be possible 
# we need to plot histogram again on log data

# %%
plt.hist(log_data)
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=100, label='Log_data')
plt.legend()
plt.show()

# %% [markdown]
# **Square root transformation: np.sqrt**

# %%
np.sqrt(exp_data)
# Out:
# array([1.06894232, 1.56030488, 0.27701944, ..., 1.00785966, 0.98972217,
#        2.09448666])

# %%
sqrt_data=np.sqrt(exp_data)
sqrt_data
# Out:
# array([1.06894232, 1.56030488, 0.27701944, ..., 1.00785966, 0.98972217,
#        2.09448666])

# %%
plt.hist(sqrt_data)
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,bins=100,label='sqrt_data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(2,2,2).hist(log_data,bins=100,label='log_data')
plt.legend()
plt.subplot(2,2,3).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(2,2,4).hist(sqrt_data,bins=100,label='sqrt_data')
plt.legend()
plt.show()

# %% [markdown]
# **Power Transformation**
#
#   - Power Transformation is used to reduce the skewnes, so that distribution become symmetric
#
#   - Under these two types are there
#
#     - Box cox Transformation
#
#     - It applies to only positive data
#
#     - It has both log transformation and square root transformation
#
# <img id="dimg_qI5EaK3aC8uR1e8PzM31wAQ_345" src="data:image/png;base64,..." class="YQ4gaf" height="118" style="object-position:45% 63%" width="428" alt="Power Transformations In Machine Learning" data-csiid="qI5EaK3aC8uR1e8PzM31wAQ_10" data-atf="1">

# %% [markdown]
# - lambda=1: No Transformation
#
# - lambda=0: Log Transformation
#
# - lambda=0.5: Square root transformation

# %%
**your job is to know about another method**
yep-Johnson **** formaula tricky confused tomorrow I will ask you

# %% [markdown]
# - power transformations are under sklearn package
#
# - sklearn
#
#   - preprossing
#
#     - power Transformation

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')
exp_data=exp_data.reshape(-1,1)
trans_exp=pt.fit_transform(exp_data)
plt.hist(trans_exp,bins=100)
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='box-cox')
exp_data=exp_data.reshape(-1,1)
trans_exp=pt.fit_transform(exp_data)
plt.hist(trans_exp,bins=100)
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')
exp_data=exp_data.reshape(-1,1)
trans_exp=pt.fit_transform(exp_data)
trans_sqrt=np.sqrt(trans_exp)
plt.hist(trans_sqrt,bins=100)
plt.show()
